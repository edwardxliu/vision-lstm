# %%
import os
import random
import itertools
import torch
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, random_split, DataLoader, Subset, ConcatDataset
from PIL import Image
import torchvision.models as models
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from sklearn.metrics import f1_score
import torch.nn.functional as F
import torch.nn as nn
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
# %matplotlib inline

# %%
from time import time
import torchvision.transforms as transforms

# %%
from datetime import datetime

# %%
# DATA_DIR = 'E:/Dataset/NWPURESISC_45/'

# TRAIN_DIR = DATA_DIR + 'train'
# TEST_DIR = DATA_DIR + 'test'

from torch.utils.data import DataLoader
from torchvision import datasets, transforms

CIFAR_MEAN = (0.4914, 0.4822, 0.4465)
CIFAR_STD  = (0.2023, 0.1994, 0.2010)

train_tf = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD),
])

test_tf = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD),
])

# %%
classes = os.listdir(TRAIN_DIR)
classes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 classes = os.listdir(TRAIN_DIR)
#       2 classes
#
# NameError: name 'TRAIN_DIR' is not defined

# %%
print('TRAIN')
for label in classes:
    files = os.listdir('{}/{}'.format(TRAIN_DIR, label))
    print('{} {} \t {}'.format(len(files), label, files[:3]))

print()
print('TEST')
for label in classes:
    files = os.listdir('{}/{}'.format(TEST_DIR, label))
    print('{} {} \t {}'.format(len(files), label, files[:3]))

# %%
import torchvision.transforms as T
def _my_normalization(x):
    return x + (0.01**0.5)*torch.randn(x.shape)


transform = T.Compose([
T.Pad(16), # Use 8 or 16 for 256 data
T.RandomRotation([-5,5]), # Start here, increas
T.Resize(64),
T.RandomCrop(64),
#T.ColorJitter(brightness=0.5,contrast=0.5, saturation=0.5),    
T.ToTensor(),
#T.Lambda(_my_normalization),
         
#T.Normalize(mean=[0.36801723, 0.3809769, 0.34357962], std=[0.20345809, 0.18542756, 0.18488906], inplace=False),
#T.NoiseInjection(p=0.5, mean=0, std=0.5), # Write a nn.Module that adds
# randn_like to data. Suggest giving it a weight. Forward is
# data = data if torch.rand(1) > self.p else data + self.weight * (self.mean + (self.std * torch.randn_like(data)))
])

# train_dataset = ImageFolder(TRAIN_DIR, transform=transform)
# test_dataset = ImageFolder(TEST_DIR, transform=transform)


print("Downloading/Preparing CIFAR-10…")
train_dataset = datasets.CIFAR10(root="../data", train=True,  download=True, transform=train_tf)
test_dataset   = datasets.CIFAR10(root="../data", train=False, download=True, transform=test_tf)

len(train_dataset), len(test_dataset)
# Out:
# Downloading/Preparing CIFAR-10…
# Files already downloaded and verified
# Files already downloaded and verified
# (50000, 10000)

# %%
def show_sample(img, label):
    plt.title('Label: {}, ({})'.format(classes[label], label))
    plt.imshow(img.permute(1, 2, 0))

# %%
index = random.randrange(len(train_dataset))
show_sample(*train_dataset[index])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 index = random.randrange(len(train_dataset))
# ----> 2 show_sample(*train_dataset[index])
#
# Cell In[13], line 2, in show_sample(img, label)
#       1 def show_sample(img, label):
# ----> 2     plt.title('Label: {}, ({})'.format(classes[label], label))
#       3     plt.imshow(img.permute(1, 2, 0))
#
# NameError: name 'classes' is not defined

# %%
index = random.randrange(len(train_dataset))
show_sample(*train_dataset[index])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 index = random.randrange(len(train_dataset))
# ----> 2 show_sample(*train_dataset[index])
#
# NameError: name 'show_sample' is not defined

# %%
random_seed = 42
torch.manual_seed(random_seed)

# %%
train_subset = train_dataset
test_subset = test_dataset
len(train_subset), len(test_subset)
# Out:
# (50000, 10000)

# %%
val_size = int(len(test_subset) * 0.3)
test_size = len(test_subset) - val_size

test_subset, val_subset = random_split(test_subset, [test_size, val_size])
len(train_subset), len(val_subset), len(test_subset)
# Out:
# (50000, 3000, 7000)

# %%
batch_size=64

# %%
# train_dataloader = DataLoader(train_subset, batch_size, shuffle=True, pin_memory=True)
# val_dataloader = DataLoader(val_subset, batch_size,  pin_memory=True)
# test_dataloader = DataLoader(test_subset, batch_size, pin_memory=True)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,  num_workers=4, pin_memory=True)
test_dataloader   = DataLoader(test_dataset,   batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
print(f"Data ready → train: {len(train_dataset)}, val: {len(test_dataset)}")
# Out:
# Data ready → train: 50000, val: 10000

# %%
def show_batch(dl, invert=False):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(16, 16))
        ax.set_xticks([]); ax.set_yticks([])
        data = 1-images if invert else images
        ax.imshow(make_grid(images[:32], nrow=8).permute(1, 2, 0))
        break

# %%
show_batch(train_dataloader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
# general imports
import torch
from torch import nn
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import torch.nn.functional as F

# %%
# initialize device
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(torch.cuda.get_device_name())
else:
    device = torch.device("cpu")
print(device)
# Out:
# NVIDIA GeForce RTX 2070 Super
# cuda

# %%
# create model
from vision_lstm3 import VisionLSTM2

model = VisionLSTM2(
    dim=192,
    #dim=128,
    #input_shape=(3, 64, 64),
    input_shape=(3, 32, 32),
    patch_size=4,
    depth=2,
    #output_shape=(45,),
    output_shape=(10,),
    mode="classifier",
    pooling="bilateral_flatten",
    #drop_path_rate=0.1,
    drop_path_rate=0,
    drop_path_decay=True,
    stride=None,
    legacy_norm=False,
    conv_kind="2d",
    conv_kernel_size=3,
    proj_bias=True,
    norm_bias=True,
    feature_extractor_channels=[32, 64, 128, 192],  # Example channel sizes for each layer
    #feature_extractor_channels=[16, 32, 64, 128],  # Example channel sizes for each layer
    use_fourier=True  # Enable wavelet transform
).to(device)

# %%
from CosineScheduler import CosineScheduler
lr = 0.001

optimizer = torch.optim.AdamW(model.parameters(), lr=lr, betas=(0.9, 0.999), eps=1e-08, weight_decay=0.01)
criterion = nn.CrossEntropyLoss(label_smoothing=0.5)

nepochs = 50
warmup=5
linear_wi=True
scheduler = CosineScheduler(optimizer,total_epochs=nepochs,
                            warmup=warmup,
                            linear_wu=linear_wi)

# %%
import torch
from torch.cuda.amp import autocast, GradScaler
from time import time
from datetime import datetime
import matplotlib.pyplot as plt
from tqdm import tqdm

scaler = GradScaler()  # Initialize the gradient scaler for mixed precision

@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def Train(epoch, print_every=30):
    model.train()
    total_loss = 0
    start_time = time()
    
    accuracy = []
    
    for i, batch in enumerate(train_dataloader, 1):
        minput = batch[0]  # Get batch of images from our train dataloader
        target = batch[1]  # Get the corresponding target
        minput, target = minput.to(device), target.to(device)
        
        moutput = model(minput)  # output by our model
        
        loss = criterion(moutput, target)  # compute cross-entropy loss
        total_loss += loss.item()

        optimizer.zero_grad()  # Clear the gradients
        loss.backward()  # Backpropagate the loss
        optimizer.step()  # Update Model parameters
        scheduler.step()
        
        argmax = moutput.argmax(dim=1)  # Get the class index with maximum probability predicted by the model
        accuracy.append((target == argmax).sum().item() / target.shape[0])  # calculate accuracy

        if i % print_every == 0:
            print(f'Epoch: [{epoch}/{num_epochs}], Step: [{i}/{len(train_dataloader)}], '
                  f'Train Loss: {loss.item():.4f}, Accuracy: {sum(accuracy)/len(accuracy):.2f}, '
                  f'Time: {time() - start_time:.2f} sec')
    
    avg_train_accuracy = sum(accuracy) / len(accuracy) if accuracy else 0
    return total_loss / len(train_dataloader), avg_train_accuracy  # Returning Average Training Loss and Accuracy

def Test(epoch):
    model.eval()
    total_loss = 0
    start_time = time()

    accuracy = []
    
    with torch.inference_mode():  # Disable gradient calculations
        #for i, batch in enumerate(val_dataloader):
        for i, batch in enumerate(test_dataloader):
            minput = batch[0]  # Get batch of images from our test dataloader
            target = batch[1]  # Get the corresponding target
            minput, target = minput.to(device), target.to(device)
            
            moutput = model(minput)  # output by our model

            loss = criterion(moutput, target)  # compute cross-entropy loss
            total_loss += loss.item()
            
            argmax = moutput.argmax(dim=1)  # Find the class with maximum score
            accuracy.append((target == argmax).sum().item() / target.shape[0])  # Calculate accuracy
            
    #avg_loss = total_loss / len(val_dataloader)
    avg_loss = total_loss / len(test_dataloader)
    avg_accuracy = sum(accuracy) / len(accuracy) if accuracy else 0
    
    print(f'Epoch: [{epoch}/{num_epochs}], Test Loss: {avg_loss:.4f}, '
          f'Accuracy: {avg_accuracy:.2f}, Time: {time() - start_time:.2f} sec')
    
    return avg_loss, avg_accuracy  # Returning Average Testing Loss and Accuracy

# Initialize variables for tracking the best model
best_loss = float('inf')
best_model_wts = None

train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []

# %%
start_time = datetime.now()

num_epochs = 20  # Set the number of epochs

for epoch in range(1, num_epochs + 1):
    train_loss, train_accuracy = Train(epoch, print_every=10)
    test_loss, test_accuracy = Test(epoch)
    
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)
    
    # Check if the current model is the best so far
    if test_loss < best_loss:
        best_loss = test_loss
        best_model_wts = model.state_dict()  # Save the best model's weights
    
    torch.cuda.empty_cache()  # Clear cached memory
    
    print('\n')

# Save the best model after all epochs are completed
if best_model_wts is not None:
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'VixLSTM_best_model_UCMerced.pth')
    print(f'Best model saved with loss: {best_loss:.4f}')

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Epoch: [1/20], Step: [10/782], Train Loss: 2.3066, Accuracy: 0.10, Time: 30.48 sec
# Epoch: [1/20], Step: [20/782], Train Loss: 2.3131, Accuracy: 0.11, Time: 33.31 sec
# Epoch: [1/20], Step: [30/782], Train Loss: 2.2756, Accuracy: 0.12, Time: 36.15 sec
# Epoch: [1/20], Step: [40/782], Train Loss: 2.2619, Accuracy: 0.14, Time: 39.00 sec
# Epoch: [1/20], Step: [50/782], Train Loss: 2.2705, Accuracy: 0.15, Time: 41.83 sec
# Epoch: [1/20], Step: [60/782], Train Loss: 2.2458, Accuracy: 0.15, Time: 44.67 sec
# Epoch: [1/20], Step: [70/782], Train Loss: 2.2526, Accuracy: 0.16, Time: 47.50 sec
# Epoch: [1/20], Step: [80/782], Train Loss: 2.2608, Accuracy: 0.17, Time: 50.32 sec
# Epoch: [1/20], Step: [90/782], Train Loss: 2.2149, Accuracy: 0.17, Time: 53.16 sec
# Epoch: [1/20], Step: [100/782], Train Loss: 2.2182, Accuracy: 0.18, Time: 56.00 sec
# Epoch: [1/20], Step: [110/782], Train Loss: 2.1968, Accuracy: 0.19, Time: 58.85 sec
# Epoch: [1/20], Step: [120/782], Train Loss: 2.1926, Accuracy: 0.19, Time: 61.69 sec
# Epoch: [1/20], Step: [130/782], Train Loss: 2.2052, Accuracy: 0.20, Time: 64.51 sec
# Epoch: [1/20], Step: [140/782], Train Loss: 2.2014, Accuracy: 0.20, Time: 67.32 sec
# Epoch: [1/20], Step: [150/782], Train Loss: 2.2445, Accuracy: 0.21, Time: 70.15 sec
# Epoch: [1/20], Step: [160/782], Train Loss: 2.2198, Accuracy: 0.21, Time: 72.98 sec
# Epoch: [1/20], Step: [170/782], Train Loss: 2.2252, Accuracy: 0.21, Time: 75.83 sec
# Epoch: [1/20], Step: [180/782], Train Loss: 2.1965, Accuracy: 0.21, Time: 78.65 sec
# Epoch: [1/20], Step: [190/782], Train Loss: 2.2601, Accuracy: 0.22, Time: 81.47 sec
# Epoch: [1/20], Step: [200/782], Train Loss: 2.1856, Accuracy: 0.22, Time: 83.92 sec
# Epoch: [1/20], Step: [210/782], Train Loss: 2.1999, Accuracy: 0.23, Time: 85.82 sec
# Epoch: [1/20], Step: [220/782], Train Loss: 2.1658, Accuracy: 0.23, Time: 87.72 sec
# Epoch: [1/20], Step: [230/782], Train Loss: 2.1979, Accuracy: 0.23, Time: 89.61 sec
# Epoch: [1/20], Step: [240/782], Train Loss: 2.2031, Accuracy: 0.24, Time: 91.51 sec
# Epoch: [1/20], Step: [250/782], Train Loss: 2.2580, Accuracy: 0.24, Time: 92.84 sec
# Epoch: [1/20], Step: [260/782], Train Loss: 2.1671, Accuracy: 0.24, Time: 93.74 sec
# Epoch: [1/20], Step: [270/782], Train Loss: 2.1912, Accuracy: 0.25, Time: 94.61 sec
# Epoch: [1/20], Step: [280/782], Train Loss: 2.1724, Accuracy: 0.25, Time: 95.47 sec
# Epoch: [1/20], Step: [290/782], Train Loss: 2.1813, Accuracy: 0.25, Time: 96.33 sec
# Epoch: [1/20], Step: [300/782], Train Loss: 2.1621, Accuracy: 0.26, Time: 97.20 sec
# Epoch: [1/20], Step: [310/782], Train Loss: 2.1779, Accuracy: 0.26, Time: 98.08 sec
# Epoch: [1/20], Step: [320/782], Train Loss: 2.1803, Accuracy: 0.26, Time: 98.94 sec
# Epoch: [1/20], Step: [330/782], Train Loss: 2.2143, Accuracy: 0.26, Time: 99.81 sec
# Epoch: [1/20], Step: [340/782], Train Loss: 2.1844, Accuracy: 0.27, Time: 100.67 sec
# Epoch: [1/20], Step: [350/782], Train Loss: 2.1528, Accuracy: 0.27, Time: 101.51 sec
# Epoch: [1/20], Step: [360/782], Train Loss: 2.1583, Accuracy: 0.27, Time: 102.40 sec
# Epoch: [1/20], Step: [370/782], Train Loss: 2.2252, Accuracy: 0.27, Time: 103.29 sec
# Epoch: [1/20], Step: [380/782], Train Loss: 2.1723, Accuracy: 0.27, Time: 104.14 sec
# Epoch: [1/20], Step: [390/782], Train Loss: 2.1485, Accuracy: 0.27, Time: 105.00 sec
# Epoch: [1/20], Step: [400/782], Train Loss: 2.1788, Accuracy: 0.28, Time: 106.67 sec
# Epoch: [1/20], Step: [410/782], Train Loss: 2.1530, Accuracy: 0.28, Time: 108.76 sec
# Epoch: [1/20], Step: [420/782], Train Loss: 2.1625, Accuracy: 0.28, Time: 110.83 sec
# Epoch: [1/20], Step: [430/782], Train Loss: 2.1651, Accuracy: 0.28, Time: 112.00 sec
# Epoch: [1/20], Step: [440/782], Train Loss: 2.1408, Accuracy: 0.29, Time: 112.87 sec
# Epoch: [1/20], Step: [450/782], Train Loss: 2.1057, Accuracy: 0.29, Time: 113.75 sec
# Epoch: [1/20], Step: [460/782], Train Loss: 2.1592, Accuracy: 0.29, Time: 114.63 sec
# Epoch: [1/20], Step: [470/782], Train Loss: 2.2268, Accuracy: 0.29, Time: 116.18 sec
# Epoch: [1/20], Step: [480/782], Train Loss: 2.1547, Accuracy: 0.29, Time: 118.10 sec
# Epoch: [1/20], Step: [490/782], Train Loss: 2.0994, Accuracy: 0.30, Time: 119.45 sec
# Epoch: [1/20], Step: [500/782], Train Loss: 2.1643, Accuracy: 0.30, Time: 120.34 sec
# Epoch: [1/20], Step: [510/782], Train Loss: 2.1670, Accuracy: 0.30, Time: 121.21 sec
# Epoch: [1/20], Step: [520/782], Train Loss: 2.1624, Accuracy: 0.30, Time: 122.10 sec
# Epoch: [1/20], Step: [530/782], Train Loss: 2.1729, Accuracy: 0.30, Time: 122.99 sec
# Epoch: [1/20], Step: [540/782], Train Loss: 2.1175, Accuracy: 0.31, Time: 123.85 sec
# Epoch: [1/20], Step: [550/782], Train Loss: 2.1575, Accuracy: 0.31, Time: 124.73 sec
# Epoch: [1/20], Step: [560/782], Train Loss: 2.1377, Accuracy: 0.31, Time: 125.60 sec
# Epoch: [1/20], Step: [570/782], Train Loss: 2.0936, Accuracy: 0.31, Time: 126.48 sec
# Epoch: [1/20], Step: [580/782], Train Loss: 2.0862, Accuracy: 0.31, Time: 127.36 sec
# Epoch: [1/20], Step: [590/782], Train Loss: 2.1353, Accuracy: 0.31, Time: 128.21 sec
# Epoch: [1/20], Step: [600/782], Train Loss: 2.1596, Accuracy: 0.32, Time: 129.07 sec
# Epoch: [1/20], Step: [610/782], Train Loss: 2.1169, Accuracy: 0.32, Time: 129.92 sec
# Epoch: [1/20], Step: [620/782], Train Loss: 2.1202, Accuracy: 0.32, Time: 130.79 sec
# Epoch: [1/20], Step: [630/782], Train Loss: 2.1365, Accuracy: 0.32, Time: 131.66 sec
# Epoch: [1/20], Step: [640/782], Train Loss: 2.1410, Accuracy: 0.32, Time: 132.55 sec
# Epoch: [1/20], Step: [650/782], Train Loss: 2.1088, Accuracy: 0.32, Time: 133.42 sec
# Epoch: [1/20], Step: [660/782], Train Loss: 2.0492, Accuracy: 0.33, Time: 134.29 sec
# Epoch: [1/20], Step: [670/782], Train Loss: 2.1169, Accuracy: 0.33, Time: 135.16 sec
# Epoch: [1/20], Step: [680/782], Train Loss: 2.1016, Accuracy: 0.33, Time: 136.03 sec
# Epoch: [1/20], Step: [690/782], Train Loss: 2.0768, Accuracy: 0.33, Time: 136.90 sec
# Epoch: [1/20], Step: [700/782], Train Loss: 2.0879, Accuracy: 0.33, Time: 137.76 sec
# Epoch: [1/20], Step: [710/782], Train Loss: 2.1866, Accuracy: 0.33, Time: 138.66 sec
# Epoch: [1/20], Step: [720/782], Train Loss: 2.1867, Accuracy: 0.33, Time: 139.65 sec
# Epoch: [1/20], Step: [730/782], Train Loss: 2.0927, Accuracy: 0.34, Time: 141.70 sec
# Epoch: [1/20], Step: [740/782], Train Loss: 2.1367, Accuracy: 0.34, Time: 143.75 sec
# Epoch: [1/20], Step: [750/782], Train Loss: 2.0866, Accuracy: 0.34, Time: 145.81 sec
# Epoch: [1/20], Step: [760/782], Train Loss: 2.0990, Accuracy: 0.34, Time: 148.34 sec
# Epoch: [1/20], Step: [770/782], Train Loss: 2.0659, Accuracy: 0.34, Time: 151.22 sec
# Epoch: [1/20], Step: [780/782], Train Loss: 2.0951, Accuracy: 0.34, Time: 154.10 sec
# Epoch: [1/20], Test Loss: 2.0904, Accuracy: 0.46, Time: 41.21 sec
#
#
# Epoch: [2/20], Step: [10/782], Train Loss: 2.1785, Accuracy: 0.44, Time: 35.54 sec
# Epoch: [2/20], Step: [20/782], Train Loss: 2.0852, Accuracy: 0.44, Time: 37.65 sec
# Epoch: [2/20], Step: [30/782], Train Loss: 2.1260, Accuracy: 0.44, Time: 39.74 sec
# Epoch: [2/20], Step: [40/782], Train Loss: 2.0608, Accuracy: 0.45, Time: 41.83 sec
# Epoch: [2/20], Step: [50/782], Train Loss: 2.0846, Accuracy: 0.46, Time: 43.90 sec
# Epoch: [2/20], Step: [60/782], Train Loss: 2.0772, Accuracy: 0.46, Time: 45.97 sec
# Epoch: [2/20], Step: [70/782], Train Loss: 2.0704, Accuracy: 0.46, Time: 47.04 sec
# Epoch: [2/20], Step: [80/782], Train Loss: 2.0985, Accuracy: 0.46, Time: 47.95 sec
# Epoch: [2/20], Step: [90/782], Train Loss: 2.1206, Accuracy: 0.47, Time: 48.85 sec
# Epoch: [2/20], Step: [100/782], Train Loss: 2.1505, Accuracy: 0.47, Time: 49.78 sec
# Epoch: [2/20], Step: [110/782], Train Loss: 2.0946, Accuracy: 0.46, Time: 50.72 sec
# Epoch: [2/20], Step: [120/782], Train Loss: 2.0739, Accuracy: 0.47, Time: 51.60 sec
# Epoch: [2/20], Step: [130/782], Train Loss: 2.0387, Accuracy: 0.47, Time: 53.40 sec
# Epoch: [2/20], Step: [140/782], Train Loss: 2.0405, Accuracy: 0.47, Time: 55.33 sec
# Epoch: [2/20], Step: [150/782], Train Loss: 2.1592, Accuracy: 0.47, Time: 56.54 sec
# Epoch: [2/20], Step: [160/782], Train Loss: 2.0841, Accuracy: 0.47, Time: 57.44 sec
# Epoch: [2/20], Step: [170/782], Train Loss: 2.1106, Accuracy: 0.47, Time: 58.32 sec
# Epoch: [2/20], Step: [180/782], Train Loss: 2.0875, Accuracy: 0.47, Time: 59.25 sec
# Epoch: [2/20], Step: [190/782], Train Loss: 2.0989, Accuracy: 0.47, Time: 60.16 sec
# Epoch: [2/20], Step: [200/782], Train Loss: 2.1396, Accuracy: 0.47, Time: 61.09 sec
# Epoch: [2/20], Step: [210/782], Train Loss: 2.0656, Accuracy: 0.47, Time: 62.01 sec
# Epoch: [2/20], Step: [220/782], Train Loss: 2.0639, Accuracy: 0.47, Time: 62.97 sec
# Epoch: [2/20], Step: [230/782], Train Loss: 2.0434, Accuracy: 0.47, Time: 63.92 sec
# Epoch: [2/20], Step: [240/782], Train Loss: 2.0187, Accuracy: 0.48, Time: 64.87 sec
# Epoch: [2/20], Step: [250/782], Train Loss: 2.0739, Accuracy: 0.48, Time: 65.78 sec
# Epoch: [2/20], Step: [260/782], Train Loss: 2.0434, Accuracy: 0.48, Time: 66.69 sec
# Epoch: [2/20], Step: [270/782], Train Loss: 2.0373, Accuracy: 0.48, Time: 67.62 sec
# Epoch: [2/20], Step: [280/782], Train Loss: 2.1096, Accuracy: 0.48, Time: 68.58 sec
# Epoch: [2/20], Step: [290/782], Train Loss: 2.1313, Accuracy: 0.48, Time: 69.58 sec
# Epoch: [2/20], Step: [300/782], Train Loss: 2.0697, Accuracy: 0.48, Time: 70.49 sec
# Epoch: [2/20], Step: [310/782], Train Loss: 2.0843, Accuracy: 0.48, Time: 71.53 sec
# Epoch: [2/20], Step: [320/782], Train Loss: 2.0241, Accuracy: 0.48, Time: 73.69 sec
# Epoch: [2/20], Step: [330/782], Train Loss: 2.0661, Accuracy: 0.48, Time: 75.86 sec
# Epoch: [2/20], Step: [340/782], Train Loss: 2.0514, Accuracy: 0.48, Time: 77.86 sec
# Epoch: [2/20], Step: [350/782], Train Loss: 2.0652, Accuracy: 0.48, Time: 78.81 sec
# Epoch: [2/20], Step: [360/782], Train Loss: 2.0634, Accuracy: 0.48, Time: 79.74 sec
# Epoch: [2/20], Step: [370/782], Train Loss: 2.0944, Accuracy: 0.49, Time: 80.66 sec
# Epoch: [2/20], Step: [380/782], Train Loss: 2.0791, Accuracy: 0.49, Time: 81.54 sec
# Epoch: [2/20], Step: [390/782], Train Loss: 1.9842, Accuracy: 0.49, Time: 82.43 sec
# Epoch: [2/20], Step: [400/782], Train Loss: 2.0603, Accuracy: 0.49, Time: 83.38 sec
# Epoch: [2/20], Step: [410/782], Train Loss: 2.0372, Accuracy: 0.49, Time: 84.32 sec
# Epoch: [2/20], Step: [420/782], Train Loss: 2.0439, Accuracy: 0.49, Time: 85.26 sec
# Epoch: [2/20], Step: [430/782], Train Loss: 1.9989, Accuracy: 0.49, Time: 86.24 sec
# Epoch: [2/20], Step: [440/782], Train Loss: 2.0959, Accuracy: 0.49, Time: 87.19 sec
# Epoch: [2/20], Step: [450/782], Train Loss: 2.0534, Accuracy: 0.49, Time: 88.50 sec
# Epoch: [2/20], Step: [460/782], Train Loss: 2.0320, Accuracy: 0.49, Time: 90.46 sec
# Epoch: [2/20], Step: [470/782], Train Loss: 2.0660, Accuracy: 0.49, Time: 92.41 sec
# Epoch: [2/20], Step: [480/782], Train Loss: 2.0905, Accuracy: 0.50, Time: 94.33 sec
# Epoch: [2/20], Step: [490/782], Train Loss: 2.0884, Accuracy: 0.50, Time: 96.27 sec
# Epoch: [2/20], Step: [500/782], Train Loss: 2.0900, Accuracy: 0.50, Time: 98.17 sec
# Epoch: [2/20], Step: [510/782], Train Loss: 1.9829, Accuracy: 0.50, Time: 100.08 sec
# Epoch: [2/20], Step: [520/782], Train Loss: 2.0179, Accuracy: 0.50, Time: 102.00 sec
# Epoch: [2/20], Step: [530/782], Train Loss: 2.0370, Accuracy: 0.50, Time: 103.91 sec
# Epoch: [2/20], Step: [540/782], Train Loss: 2.0386, Accuracy: 0.50, Time: 105.83 sec
# Epoch: [2/20], Step: [550/782], Train Loss: 2.0320, Accuracy: 0.50, Time: 107.73 sec
# Epoch: [2/20], Step: [560/782], Train Loss: 2.0440, Accuracy: 0.50, Time: 110.18 sec
# Epoch: [2/20], Step: [570/782], Train Loss: 2.0117, Accuracy: 0.50, Time: 113.09 sec
# Epoch: [2/20], Step: [580/782], Train Loss: 2.1245, Accuracy: 0.50, Time: 116.02 sec
# Epoch: [2/20], Step: [590/782], Train Loss: 2.0758, Accuracy: 0.50, Time: 118.96 sec
# Epoch: [2/20], Step: [600/782], Train Loss: 2.0333, Accuracy: 0.50, Time: 121.86 sec
# Epoch: [2/20], Step: [610/782], Train Loss: 2.0031, Accuracy: 0.51, Time: 124.78 sec
# Epoch: [2/20], Step: [620/782], Train Loss: 2.0896, Accuracy: 0.51, Time: 127.70 sec
# Epoch: [2/20], Step: [630/782], Train Loss: 2.0466, Accuracy: 0.51, Time: 130.64 sec
# Epoch: [2/20], Step: [640/782], Train Loss: 1.9896, Accuracy: 0.51, Time: 133.58 sec
# Epoch: [2/20], Step: [650/782], Train Loss: 2.0649, Accuracy: 0.51, Time: 136.47 sec
# Epoch: [2/20], Step: [660/782], Train Loss: 2.0332, Accuracy: 0.51, Time: 139.34 sec
# Epoch: [2/20], Step: [670/782], Train Loss: 2.0483, Accuracy: 0.51, Time: 142.25 sec
# Epoch: [2/20], Step: [680/782], Train Loss: 2.0294, Accuracy: 0.51, Time: 145.22 sec
# Epoch: [2/20], Step: [690/782], Train Loss: 1.9908, Accuracy: 0.51, Time: 148.16 sec
# Epoch: [2/20], Step: [700/782], Train Loss: 2.0065, Accuracy: 0.51, Time: 151.09 sec
# Epoch: [2/20], Step: [710/782], Train Loss: 1.9436, Accuracy: 0.51, Time: 154.04 sec
# Epoch: [2/20], Step: [720/782], Train Loss: 2.0585, Accuracy: 0.51, Time: 156.97 sec
# Epoch: [2/20], Step: [730/782], Train Loss: 1.9937, Accuracy: 0.51, Time: 159.91 sec
# Epoch: [2/20], Step: [740/782], Train Loss: 1.9977, Accuracy: 0.52, Time: 162.83 sec
# Epoch: [2/20], Step: [750/782], Train Loss: 1.9773, Accuracy: 0.52, Time: 165.72 sec
# Epoch: [2/20], Step: [760/782], Train Loss: 2.0022, Accuracy: 0.52, Time: 168.61 sec
# Epoch: [2/20], Step: [770/782], Train Loss: 2.0750, Accuracy: 0.52, Time: 171.50 sec
# Epoch: [2/20], Step: [780/782], Train Loss: 1.9676, Accuracy: 0.52, Time: 174.39 sec
# Epoch: [2/20], Test Loss: 2.0039, Accuracy: 0.59, Time: 37.70 sec
#
#
# Epoch: [3/20], Step: [10/782], Train Loss: 2.0288, Accuracy: 0.59, Time: 32.91 sec
# Epoch: [3/20], Step: [20/782], Train Loss: 2.0081, Accuracy: 0.59, Time: 34.82 sec
# Epoch: [3/20], Step: [30/782], Train Loss: 2.0268, Accuracy: 0.59, Time: 36.73 sec
# Epoch: [3/20], Step: [40/782], Train Loss: 2.0536, Accuracy: 0.59, Time: 39.41 sec
# Epoch: [3/20], Step: [50/782], Train Loss: 2.0163, Accuracy: 0.59, Time: 42.36 sec
# Epoch: [3/20], Step: [60/782], Train Loss: 1.9989, Accuracy: 0.60, Time: 45.39 sec
# Epoch: [3/20], Step: [70/782], Train Loss: 1.9453, Accuracy: 0.59, Time: 47.39 sec
# Epoch: [3/20], Step: [80/782], Train Loss: 2.0213, Accuracy: 0.60, Time: 49.39 sec
# Epoch: [3/20], Step: [90/782], Train Loss: 2.0259, Accuracy: 0.60, Time: 51.33 sec
# Epoch: [3/20], Step: [100/782], Train Loss: 2.0330, Accuracy: 0.60, Time: 53.31 sec
# Epoch: [3/20], Step: [110/782], Train Loss: 2.0108, Accuracy: 0.60, Time: 55.23 sec
# Epoch: [3/20], Step: [120/782], Train Loss: 2.0152, Accuracy: 0.60, Time: 57.15 sec
# Epoch: [3/20], Step: [130/782], Train Loss: 2.0331, Accuracy: 0.60, Time: 59.13 sec
# Epoch: [3/20], Step: [140/782], Train Loss: 1.9993, Accuracy: 0.60, Time: 61.04 sec
# Epoch: [3/20], Step: [150/782], Train Loss: 2.0116, Accuracy: 0.60, Time: 62.95 sec
# Epoch: [3/20], Step: [160/782], Train Loss: 1.9340, Accuracy: 0.60, Time: 64.89 sec
# Epoch: [3/20], Step: [170/782], Train Loss: 2.0440, Accuracy: 0.60, Time: 66.82 sec
# Epoch: [3/20], Step: [180/782], Train Loss: 1.9795, Accuracy: 0.60, Time: 68.75 sec
# Epoch: [3/20], Step: [190/782], Train Loss: 2.0413, Accuracy: 0.60, Time: 70.65 sec
# Epoch: [3/20], Step: [200/782], Train Loss: 2.0439, Accuracy: 0.60, Time: 72.57 sec
# Epoch: [3/20], Step: [210/782], Train Loss: 1.9460, Accuracy: 0.60, Time: 74.49 sec
# Epoch: [3/20], Step: [220/782], Train Loss: 2.0051, Accuracy: 0.60, Time: 76.63 sec
# Epoch: [3/20], Step: [230/782], Train Loss: 1.9575, Accuracy: 0.60, Time: 79.56 sec
# Epoch: [3/20], Step: [240/782], Train Loss: 1.9540, Accuracy: 0.60, Time: 82.50 sec
# Epoch: [3/20], Step: [250/782], Train Loss: 1.9788, Accuracy: 0.61, Time: 85.44 sec
# Epoch: [3/20], Step: [260/782], Train Loss: 1.9691, Accuracy: 0.61, Time: 88.40 sec
# Epoch: [3/20], Step: [270/782], Train Loss: 1.9968, Accuracy: 0.61, Time: 91.35 sec
# Epoch: [3/20], Step: [280/782], Train Loss: 1.9210, Accuracy: 0.61, Time: 94.29 sec
# Epoch: [3/20], Step: [290/782], Train Loss: 1.9956, Accuracy: 0.61, Time: 97.25 sec
# Epoch: [3/20], Step: [300/782], Train Loss: 1.9421, Accuracy: 0.61, Time: 100.17 sec
# Epoch: [3/20], Step: [310/782], Train Loss: 1.9881, Accuracy: 0.61, Time: 103.10 sec
# Epoch: [3/20], Step: [320/782], Train Loss: 1.9968, Accuracy: 0.61, Time: 105.98 sec
# Epoch: [3/20], Step: [330/782], Train Loss: 1.9525, Accuracy: 0.61, Time: 108.87 sec
# Epoch: [3/20], Step: [340/782], Train Loss: 1.9491, Accuracy: 0.61, Time: 111.77 sec
# Epoch: [3/20], Step: [350/782], Train Loss: 1.9723, Accuracy: 0.61, Time: 114.66 sec
# Epoch: [3/20], Step: [360/782], Train Loss: 2.0119, Accuracy: 0.61, Time: 117.55 sec
# Epoch: [3/20], Step: [370/782], Train Loss: 1.9845, Accuracy: 0.61, Time: 120.43 sec
# Epoch: [3/20], Step: [380/782], Train Loss: 2.0216, Accuracy: 0.61, Time: 122.89 sec
# Epoch: [3/20], Step: [390/782], Train Loss: 2.0136, Accuracy: 0.61, Time: 125.03 sec
# Epoch: [3/20], Step: [400/782], Train Loss: 2.0115, Accuracy: 0.61, Time: 127.14 sec
# Epoch: [3/20], Step: [410/782], Train Loss: 1.9456, Accuracy: 0.61, Time: 129.23 sec
# Epoch: [3/20], Step: [420/782], Train Loss: 2.0135, Accuracy: 0.61, Time: 131.35 sec
# Epoch: [3/20], Step: [430/782], Train Loss: 1.9661, Accuracy: 0.61, Time: 133.46 sec
# Epoch: [3/20], Step: [440/782], Train Loss: 1.9908, Accuracy: 0.61, Time: 135.58 sec
# Epoch: [3/20], Step: [450/782], Train Loss: 1.9709, Accuracy: 0.61, Time: 137.73 sec
# Epoch: [3/20], Step: [460/782], Train Loss: 1.9296, Accuracy: 0.61, Time: 139.89 sec
# Epoch: [3/20], Step: [470/782], Train Loss: 1.9191, Accuracy: 0.61, Time: 141.99 sec
# Epoch: [3/20], Step: [480/782], Train Loss: 2.0179, Accuracy: 0.61, Time: 144.11 sec
# Epoch: [3/20], Step: [490/782], Train Loss: 1.9443, Accuracy: 0.61, Time: 146.22 sec
# Epoch: [3/20], Step: [500/782], Train Loss: 1.9789, Accuracy: 0.61, Time: 148.91 sec
# Epoch: [3/20], Step: [510/782], Train Loss: 2.0463, Accuracy: 0.61, Time: 151.79 sec
# Epoch: [3/20], Step: [520/782], Train Loss: 2.0116, Accuracy: 0.61, Time: 154.09 sec
# Epoch: [3/20], Step: [530/782], Train Loss: 1.9579, Accuracy: 0.62, Time: 156.19 sec
# Epoch: [3/20], Step: [540/782], Train Loss: 1.9209, Accuracy: 0.62, Time: 158.25 sec
# Epoch: [3/20], Step: [550/782], Train Loss: 1.9381, Accuracy: 0.62, Time: 160.30 sec
# Epoch: [3/20], Step: [560/782], Train Loss: 1.9957, Accuracy: 0.62, Time: 162.37 sec
# Epoch: [3/20], Step: [570/782], Train Loss: 1.9717, Accuracy: 0.62, Time: 164.44 sec
# Epoch: [3/20], Step: [580/782], Train Loss: 1.9999, Accuracy: 0.62, Time: 166.51 sec
# Epoch: [3/20], Step: [590/782], Train Loss: 1.9795, Accuracy: 0.62, Time: 168.58 sec
# Epoch: [3/20], Step: [600/782], Train Loss: 2.0297, Accuracy: 0.62, Time: 170.65 sec
# Epoch: [3/20], Step: [610/782], Train Loss: 1.9188, Accuracy: 0.62, Time: 172.70 sec
# Epoch: [3/20], Step: [620/782], Train Loss: 1.9752, Accuracy: 0.62, Time: 174.73 sec
# Epoch: [3/20], Step: [630/782], Train Loss: 2.0088, Accuracy: 0.62, Time: 176.80 sec
# Epoch: [3/20], Step: [640/782], Train Loss: 1.9394, Accuracy: 0.62, Time: 178.90 sec
# Epoch: [3/20], Step: [650/782], Train Loss: 1.9941, Accuracy: 0.62, Time: 180.97 sec
# Epoch: [3/20], Step: [660/782], Train Loss: 1.9882, Accuracy: 0.62, Time: 183.04 sec
# Epoch: [3/20], Step: [670/782], Train Loss: 1.9728, Accuracy: 0.62, Time: 185.27 sec
# Epoch: [3/20], Step: [680/782], Train Loss: 1.9397, Accuracy: 0.62, Time: 188.13 sec
# Epoch: [3/20], Step: [690/782], Train Loss: 1.8874, Accuracy: 0.62, Time: 191.05 sec
# Epoch: [3/20], Step: [700/782], Train Loss: 1.9523, Accuracy: 0.62, Time: 193.93 sec
# Epoch: [3/20], Step: [710/782], Train Loss: 1.9367, Accuracy: 0.62, Time: 197.02 sec
# Epoch: [3/20], Step: [720/782], Train Loss: 1.9557, Accuracy: 0.62, Time: 200.08 sec
# Epoch: [3/20], Step: [730/782], Train Loss: 1.9994, Accuracy: 0.62, Time: 203.24 sec
# Epoch: [3/20], Step: [740/782], Train Loss: 2.0058, Accuracy: 0.62, Time: 206.23 sec
# Epoch: [3/20], Step: [750/782], Train Loss: 1.9502, Accuracy: 0.62, Time: 209.12 sec
# Epoch: [3/20], Step: [760/782], Train Loss: 1.9669, Accuracy: 0.62, Time: 211.03 sec
# Epoch: [3/20], Step: [770/782], Train Loss: 1.9655, Accuracy: 0.63, Time: 212.97 sec
# Epoch: [3/20], Step: [780/782], Train Loss: 1.9640, Accuracy: 0.63, Time: 214.91 sec
# Epoch: [3/20], Test Loss: 1.9820, Accuracy: 0.62, Time: 35.23 sec
#
#
# Epoch: [4/20], Step: [10/782], Train Loss: 1.9281, Accuracy: 0.70, Time: 30.47 sec
# Epoch: [4/20], Step: [20/782], Train Loss: 1.9331, Accuracy: 0.69, Time: 33.11 sec
# Epoch: [4/20], Step: [30/782], Train Loss: 1.8757, Accuracy: 0.68, Time: 36.02 sec
# Epoch: [4/20], Step: [40/782], Train Loss: 1.9656, Accuracy: 0.67, Time: 38.28 sec
# Epoch: [4/20], Step: [50/782], Train Loss: 1.9697, Accuracy: 0.67, Time: 40.31 sec
# Epoch: [4/20], Step: [60/782], Train Loss: 1.8925, Accuracy: 0.67, Time: 42.37 sec
# Epoch: [4/20], Step: [70/782], Train Loss: 1.9420, Accuracy: 0.67, Time: 44.42 sec
# Epoch: [4/20], Step: [80/782], Train Loss: 1.9008, Accuracy: 0.67, Time: 46.48 sec
# Epoch: [4/20], Step: [90/782], Train Loss: 1.9410, Accuracy: 0.68, Time: 48.54 sec
# Epoch: [4/20], Step: [100/782], Train Loss: 1.9567, Accuracy: 0.68, Time: 50.67 sec
# Epoch: [4/20], Step: [110/782], Train Loss: 1.9289, Accuracy: 0.68, Time: 52.79 sec
# Epoch: [4/20], Step: [120/782], Train Loss: 1.9201, Accuracy: 0.68, Time: 54.92 sec
# Epoch: [4/20], Step: [130/782], Train Loss: 1.9129, Accuracy: 0.67, Time: 57.01 sec
# Epoch: [4/20], Step: [140/782], Train Loss: 2.0030, Accuracy: 0.68, Time: 59.12 sec
# Epoch: [4/20], Step: [150/782], Train Loss: 1.9067, Accuracy: 0.68, Time: 61.23 sec
# Epoch: [4/20], Step: [160/782], Train Loss: 1.9180, Accuracy: 0.68, Time: 63.34 sec
# Epoch: [4/20], Step: [170/782], Train Loss: 1.9605, Accuracy: 0.68, Time: 65.43 sec
# Epoch: [4/20], Step: [180/782], Train Loss: 1.9236, Accuracy: 0.67, Time: 68.22 sec
# Epoch: [4/20], Step: [190/782], Train Loss: 1.9612, Accuracy: 0.67, Time: 71.14 sec
# Epoch: [4/20], Step: [200/782], Train Loss: 1.9520, Accuracy: 0.67, Time: 74.12 sec
# Epoch: [4/20], Step: [210/782], Train Loss: 1.9776, Accuracy: 0.68, Time: 77.03 sec
# Epoch: [4/20], Step: [220/782], Train Loss: 1.9827, Accuracy: 0.67, Time: 79.95 sec
# Epoch: [4/20], Step: [230/782], Train Loss: 1.9936, Accuracy: 0.68, Time: 82.89 sec
# Epoch: [4/20], Step: [240/782], Train Loss: 1.9712, Accuracy: 0.68, Time: 85.83 sec
# Epoch: [4/20], Step: [250/782], Train Loss: 1.9277, Accuracy: 0.68, Time: 88.74 sec
# Epoch: [4/20], Step: [260/782], Train Loss: 1.9614, Accuracy: 0.68, Time: 91.73 sec
# Epoch: [4/20], Step: [270/782], Train Loss: 1.8973, Accuracy: 0.68, Time: 94.69 sec

# %%
from torchinfo import summary

summary(model, input_size=(1, 3, 32, 32))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# VisionLSTM2                                             [1, 10]                   --
# ├─FeatureExtractor: 1-1                                 [1, 195, 32, 32]          --
# │    └─Sequential: 2-1                                  [1, 192, 32, 32]          --
# │    │    └─Conv2d: 3-1                                 [1, 32, 32, 32]           896
# │    │    └─ReLU: 3-2                                   [1, 32, 32, 32]           --
# │    │    └─Conv2d: 3-3                                 [1, 64, 32, 32]           18,496
# │    │    └─ReLU: 3-4                                   [1, 64, 32, 32]           --
# │    │    └─Conv2d: 3-5                                 [1, 128, 32, 32]          73,856
# │    │    └─ReLU: 3-6                                   [1, 128, 32, 32]          --
# │    │    └─Conv2d: 3-7                                 [1, 192, 32, 32]          221,376
# │    │    └─ReLU: 3-8                                   [1, 192, 32, 32]          --
# │    └─FourierTransform: 2-2                            [1, 3, 32, 32]            --
# ├─VitPatchEmbed: 1-2                                    [1, 8, 8, 192]            --
# │    └─Conv2d: 2-3                                      [1, 192, 8, 8]            599,232
# ├─VitPosEmbed2d: 1-3                                    [1, 8, 8, 192]            12,288
# ├─ModuleList: 1-4                                       --                        --
# │    └─ViLBlockPair: 2-4                                [1, 64, 192]              --
# │    │    └─ViLBlock: 3-9                               [1, 64, 192]              242,504
# │    │    └─ViLBlock: 3-10                              [1, 64, 192]              242,504
# │    └─ViLBlockPair: 2-5                                [1, 64, 192]              --
# │    │    └─ViLBlock: 3-11                              [1, 64, 192]              242,504
# │    │    └─ViLBlock: 3-12                              [1, 64, 192]              242,504
# ├─LayerNorm: 1-5                                        [1, 64, 192]              384
# ├─Identity: 1-6                                         [1, 384]                  --
# ├─FeatureExtractor: 1-7                                 [1, 195, 32, 32]          (recursive)
# │    └─Sequential: 2-6                                  [1, 192, 32, 32]          (recursive)
# │    │    └─Conv2d: 3-13                                [1, 32, 32, 32]           (recursive)
# │    │    └─ReLU: 3-14                                  [1, 32, 32, 32]           --
# │    │    └─Conv2d: 3-15                                [1, 64, 32, 32]           (recursive)
# │    │    └─ReLU: 3-16                                  [1, 64, 32, 32]           --
# │    │    └─Conv2d: 3-17                                [1, 128, 32, 32]          (recursive)
# │    │    └─ReLU: 3-18                                  [1, 128, 32, 32]          --
# │    │    └─Conv2d: 3-19                                [1, 192, 32, 32]          (recursive)
# │    │    └─ReLU: 3-20                                  [1, 192, 32, 32]          --
# │    └─FourierTransform: 2-7                            [1, 3, 32, 32]            --
# ├─Sequential: 1-8                                       [1, 192]                  --
# │    └─Conv2d: 2-8                                      [1, 1, 32, 32]            1,756
# │    └─ReLU: 2-9                                        [1, 1, 32, 32]            --
# │    └─Flatten: 2-10                                    [1, 1024]                 --
# │    └─Linear: 2-11                                     [1, 256]                  262,400
# │    └─ReLU: 2-12                                       [1, 256]                  --
# │    └─Linear: 2-13                                     [1, 192]                  49,344
# ├─Linear: 1-9                                           [1, 10]                   5,770
# =========================================================================================================
# Total params: 2,215,814
# Trainable params: 2,215,814
# Non-trainable params: 0
# Total mult-adds (M): 691.67
# =========================================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 13.43
# Params size (MB): 8.86
# Estimated Total Size (MB): 22.30
# =========================================================================================================

# %%
@torch.no_grad()
def predictions(model, dataloader):
    torch.cuda.empty_cache()
    preds_list = torch.zeros(0, dtype=torch.long, device=device)
    labels_list = torch.zeros(0, dtype=torch.long, device=device)
    for i, batch in enumerate(dataloader):
        images, labels = batch
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, preds  = torch.max(outputs, dim=1)
        preds_list = torch.cat((preds_list, preds), 0)
        labels_list = torch.cat((labels_list, labels), 0)
    return preds_list, labels_list

# %%
preds_list, labels_list = predictions(model, test_dataloader)

# %%
from sklearn.metrics import classification_report,recall_score,cohen_kappa_score,accuracy_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from typing import List

def plot_confusion(cm: np.ndarray, classes: List[str], title="Confusion Matrix"):
    """画混淆矩阵（单图，无 seaborn）"""
    fig, ax = plt.subplots(figsize=(8,6))
    im = ax.imshow(cm, interpolation='nearest')
    ax.set_title(title)
    plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    ticks = np.arange(len(classes))
    ax.set_xticks(ticks); ax.set_yticks(ticks)
    ax.set_xticklabels(classes, rotation=45, ha='right')
    ax.set_yticklabels(classes)
    ax.set_ylabel('True'); ax.set_xlabel('Pred')
    thr = cm.max() * 0.6
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            val = cm[i,j]
            ax.text(j, i, int(val), ha='center', va='center',
                    color='white' if val > thr else 'black', fontsize=8)
    fig.tight_layout()
    plt.show()
    
preds_list, labels_list = predictions(model, test_dataloader)
preds_list, labels_list

#SAVE_PATH='E:/Results/'
CLASSES = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
## classfication report
# test_pred = preds_list.cpu()
# test_true = labels_list.cpu()

y_pred = preds_list.cpu()
y_te = labels_list.cpu()

acc = accuracy_score(y_te, y_pred)
print(f"[test] Accuracy: {acc*100:.2f}%")

cm = confusion_matrix(y_te, y_pred, labels=list(range(10)))
plot_confusion(cm, CLASSES, title=f"Confusion, acc={acc*100:.2f}%)")
print("\nClassification Report:\n", classification_report(y_te, y_pred, target_names=CLASSES))

# OA = accuracy_score(test_true,test_pred)
# AA = recall_score(test_true,test_pred,average='macro')
# kappa = cohen_kappa_score(test_true,test_pred)
# report_log = F"OA: {OA}\nAA: {AA}\nKappa: {kappa}\n"
# report_log += classification_report(test_true,test_pred,target_names=classes,digits=4)
#print(report_log)
# fp = open(os.path.join(SAVE_PATH,'ViCxLSTM_classfication_report_NWPURESISC_45.txt'),'w+')
# fp.writelines(report_log)
# fp.close()
# Out:
# [test] Accuracy: 87.68%
# Classification Report:
#                precision    recall  f1-score   support
#
#     airplane       0.89      0.89      0.89      1000
#   automobile       0.97      0.91      0.94      1000
#         bird       0.86      0.84      0.85      1000
#          cat       0.73      0.80      0.76      1000
#         deer       0.89      0.85      0.87      1000
#          dog       0.86      0.79      0.82      1000
#         frog       0.90      0.92      0.91      1000
#        horse       0.92      0.89      0.90      1000
#         ship       0.95      0.91      0.93      1000
#        truck       0.85      0.97      0.91      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
#
# OA: 0.8768
# AA: 0.8767999999999999
# Kappa: 0.8631111111111112
#               precision    recall  f1-score   support
#
#     airplane     0.8863    0.8890    0.8877      1000
#   automobile     0.9662    0.9140    0.9394      1000
#         bird     0.8566    0.8360    0.8462      1000
#          cat     0.7264    0.7990    0.7610      1000
#         deer     0.8868    0.8540    0.8701      1000
#          dog     0.8575    0.7880    0.8213      1000
#         frog     0.8950    0.9210    0.9078      1000
#        horse     0.9209    0.8850    0.9026      1000
#         ship     0.9462    0.9140    0.9298      1000
#        truck     0.8514    0.9680    0.9059      1000
#
#     accuracy                         0.8768     10000
#    macro avg     0.8793    0.8768    0.8772     10000
# weighted avg     0.8793    0.8768    0.8772     10000
